# %% [markdown]
# ## OpenMP Trace Investigation

# %% [markdown]
# The goal of this investigation is to determine how to extract load information from `OpenMP` traces (generated with [`ScoreP`](http://www.vi-hps.org/projects/score-p/)) correctly. The application used in this report, `floorplan`, was obtained from the [Barcelona OpenMP Task Suite](https://pm.bsc.es/projects/bots).
#
# First, the Julia modules that will be needed should be imported.

# %%
using DataFrames
using Gadfly
using YAJP

# %% [markdown]
# In the cell bellow, the _tied tasks_ version of the application is parsed, according to `floorplan-tied.yaml` (shown right after).

# %%
tied = trace("floorplan-tied.csv", "floorplan-tied.yaml")
# Out:
# Trace holding 4 Containers, 5434 kept Events, and 135 discarded Events.

# %%
for l in readall("floorplan-tied.yaml")
    print(l)
end
# Out:
# containers:
#     - THREAD
# states:
#     - STATE
# keep:
#     - "!$omp create task @tied-floorplan.c:530 <3>"
#     - "!$omp task @tied-floorplan.c:530 <4>"
# discard:
#     - "!$omp taskwait @tied-floorplan.c:584 <8>"
# # ignored:
#     # "!$omp parallel @tied-floorplan.c:620 <9>"
#     # "!$omp single @tied-floorplan.c:622 <11>"
#     # "!$omp single sblock @tied-floorplan.c:622 <12>"
#     # "!$omp atomic @tied-floorplan.c:572 <7>"
#     # "!$omp critical @tied-floorplan.c:560 <5>"
#     # "!$omp critical sblock @tied-floorplan.c:560 <6>"
#     # "!$omp implicit barrier @tied-floorplan.c:628 <10>"
#     # "!$omp implicit barrier @tied-floorplan.c:626 <13>"

# %% [markdown]
# The yaml file says to `YAJP` that it should consider all containers of type `THREAD`. Also, the file determines that within those containers, states of type `STATE` that are listed either in `keep` or in `discard` are the only types to be considered (i.e. parsed). When determining the load, _kept_ events are added and _discard_ events are subtracted.

# %% [markdown]
# To see if the parsing of the trace promoted above makes sense, the normalized load is plotted. Normalized load values should be within 0 and 1. Hence, if any resource (i.e. thread) posseses a load that is not contained in that range, the parsing is incorrect.

# %%
set_default_plot_size(12cm,14cm)
plot(loads(tied), x="container", y="normalized", Geom.bar,
    Theme(bar_spacing=4pt))
# Out:
# Plot(...)

# %% [markdown]
# It is clear that the parsing proposed by the `yaml` file is not the right way to obtain the load from the OpenMP application.
#
# The same process is performed for a version of the application with _untied tasks_.

# %%
untied = trace("floorplan-untied.csv", "floorplan-untied.yaml")
# Out:
# Trace holding 4 Containers, 5362 kept Events, and 134 discarded Events.

# %%
for l in readall("floorplan-untied.yaml")
    print(l)
end
# Out:
# containers:
#     - THREAD
# states:
#     - STATE
# keep:
#     - "!$omp create task @floorplan.c:530 <3>"
#     - "!$omp task @floorplan.c:530 <4>"
# discard:
#     - "!$omp taskwait @floorplan.c:584 <8>"
# # ignored:
#     # "!$omp implicit barrier @floorplan.c:626 <13>"
#     # "!$omp implicit barrier @floorplan.c:628 <10>"
#     # "!$omp atomic @floorplan.c:572 <7>"
#     # "!$omp critical @floorplan.c:560 <5>"
#     # "!$omp critical sblock @floorplan.c:560 <6>"
#     # "!$omp parallel @floorplan.c:620 <9>"
#     # "!$omp single @floorplan.c:622 <11>"
#     # "!$omp single sblock @floorplan.c:622 <12>"

# %% [markdown]
# The same logic explained before applies here. Below, follows the load.

# %%
set_default_plot_size(12cm,14cm)
plot(loads(untied), x="container", y="normalized", Geom.bar,
    Theme(bar_spacing=4pt))
# Out:
# Plot(...)

# %% [markdown]
# Again, the negative load of container `zero` is indicative of the failure in obtaining the load according to the `yaml` file as it is.
